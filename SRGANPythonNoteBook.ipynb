# %%
mount_drive = True
if mount_drive:
    from google.colab import drive
    drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import torch

# check the allocation machine
isCuda = torch.cuda.is_available()
machine = torch.cuda.get_device_properties(0) if isCuda else 'cpu'
print("Assigned Machine: ", machine)
device = torch.device('cuda:0' if isCuda else 'cpu')
print(f"cuda avaiable: {isCuda}, Device: {device}")
# Out:
# Assigned Machine:  _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)
# cuda avaiable: True, Device: cuda:0

# %%
import os
os.chdir('/content/gdrive/My Drive/EVA4Phase2/train/Lq')
print(os.getcwd())
# Out:
# /content/gdrive/My Drive/EVA4Phase2/train/Lq

# %%
import os
os.chdir('/content/gdrive/My Drive/SRGAN')
print(os.getcwd())
# Out:
# /content/gdrive/My Drive/SRGAN

# %%
import torchvision
import torch.nn as nn
import torch.nn.functional as F

from math import log10

import pandas as pd
import torch.optim as optim
import torch.utils.data
import torchvision.utils as utils
from torch.utils.data import DataLoader
from tqdm import tqdm

import pytorch_ssim

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import autoreload
# %load_ext autoreload
# %autoreload

# %%
import shutil

# %%
from pathlib import Path

# important folders used in this application

Path(f'logs').mkdir(exist_ok=True)

SOLUTION_LOG_DIR = f"logs/logs_drone_sf2"     # root directoy for all the log of this notebook
Path(f'./{SOLUTION_LOG_DIR}').mkdir(exist_ok=True)

SAVED_MODELS_DIR = Path(f'./{SOLUTION_LOG_DIR}/saved_models') # location to save models
SAVED_MODELS_DIR.mkdir(exist_ok=True)

SAVED_RESULTS_DIR = Path(f'./{SOLUTION_LOG_DIR}/saved_results')
SAVED_RESULTS_DIR.mkdir(exist_ok=True)

PLOT_DIR = Path(f'./{SOLUTION_LOG_DIR}/doc_images')
PLOT_DIR.mkdir(exist_ok=True)

# %%
config_params = dict(
    seed=1,
    batch_size=64,
    num_workers=6,
    epochs=100,
    upscale_factor=2 
)

torch.manual_seed(config_params['seed'])
if isCuda:
   torch.cuda.manual_seed(config_params['seed'])

# %%
# dataset path where zip files are placed.
src_dataset_dir = '/content/gdrive/My Drive/EVA4Phase2/train'
src_dataset_dir1='/content/gdrive/My Drive/EVA4Phase2'

#unzip locations: note path shall be colab internal memory location not on mounted drive.
root_dataset = '/content/eva4p2_s8_dataset'

# %%
import shutil

# %%
#class_list = ['Flying Birds', 'Large QuadCopters', 'Small QuadCopters', 'Winged Drones']
classname = 'Lq' #'Small QuadCopters' ## 
class_list = [classname]

# %%
pwd
# Out:
# '/content/gdrive/My Drive/SRGAN'

# %%
import utils.data_utils as dutils
import shutil

if Path(root_dataset).exists():
  shutil.rmtree(root_dataset)

# %%
# %%time

import zipfile
def extract_dataset(fn, dest):
    with open(fn, 'rb') as f:
      zf = zipfile.ZipFile(f)
      zf.extractall(dest)
      
# create root destination folder
if not Path(root_dataset).exists():
  Path(root_dataset).mkdir(exist_ok=True)

# extract individual class zip file
for classname in class_list:
  class_zipname = f'{src_dataset_dir}/{classname}.zip'  
  class_dir = f'{root_dataset}/{classname}' # class folder unzip location
  if not Path(class_dir).exists():
    print(f'Extracting {classname} images...')
    extract_dataset(fn=class_zipname, dest=class_dir)
# Out:
# Extracting Lq images...
# CPU times: user 285 ms, sys: 67.6 ms, total: 352 ms
# Wall time: 1.54 s

# %%
from PIL import Image
import os, sys
import datetime

dst_datadir = '/content/eva4p2_s7_dataset_working'

# %%
#from PIL import Image
#import os, sys
#import datetime

#dst_datadir = 'train'

#if Path(dst_datadir).exists():
  #shutil.rmtree(dst_datadir)

# %%
dutils.prepare_dataset(root_dataset, dst_datadir, ds_limit=1000, valid_size=0.03)
# Out:
# Dataset already exist..

# %%
from utils.data_utils_srgan import TrainDatasetFromFolder, ValDatasetFromFolder, display_transform

CROP_SIZE = 88
UPSCALE_FACTOR = 2

train_set = TrainDatasetFromFolder(f'{src_dataset_dir1}/train/{classname}', crop_size=CROP_SIZE, upscale_factor=UPSCALE_FACTOR)
val_set = ValDatasetFromFolder(f'{src_dataset_dir1}/test/{classname}', upscale_factor=UPSCALE_FACTOR)
train_loader = DataLoader(dataset=train_set, num_workers=config_params["num_workers"], batch_size=config_params["batch_size"], shuffle=True)
val_loader = DataLoader(dataset=val_set, num_workers=config_params["num_workers"], batch_size=1, shuffle=False)

# %%
print(f'Train size: {len(train_loader.dataset)}')
print(f'Test size: {len(val_loader.dataset)}')
# Out:
# Train size: 976
# Test size: 30

# %%
lr_images, hr_images = next(iter(train_loader))
print(f'LR image size: {lr_images.shape}')
print(f'HR image size: {hr_images.shape}')
# Out:
# LR image size: torch.Size([64, 3, 44, 44])
# HR image size: torch.Size([64, 3, 88, 88])

# %%
def plot_dataset_images(data_loader, device, figsize=(10,9), num_of_images=20, save_filename=None):
    cnt = 0
    fig = plt.figure(figsize=figsize)
    for lr, hr in data_loader:
      data = hr.to(device)
      for index, img in enumerate(data):
        ax = fig.add_subplot(4, 5, cnt+1, xticks=[], yticks=[])
        ax.axis('on')
        npimg = img.cpu().numpy()
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

        cnt += 1
        if(cnt==num_of_images):
          break
      if(cnt==num_of_images):
        break
    if save_filename:
      fig.savefig(save_filename)
  
    return

# %%
plot_dataset_images(train_loader, device, figsize=(15,12), save_filename=f'{PLOT_DIR}/dataset_samples.jpg')

# %%
MODEL_NAME = "SRGAN"
MAX_EPOCH = config_params["epochs"]
BATCH_SIZE = config_params["batch_size"]
UPSCALE_FACTOR = config_params["upscale_factor"]

# %%
from models.srgan_net import Generator, Discriminator

netG = Generator(UPSCALE_FACTOR).to(device)
print('# generator parameters:', sum(param.numel() for param in netG.parameters()))
netD = Discriminator().to(device)
print('# discriminator parameters:', sum(param.numel() for param in netD.parameters()))
# Out:
# # generator parameters: 586506
# # discriminator parameters: 5215425

# %%
from utils.loss import GeneratorLoss
generator_criterion = GeneratorLoss().to(device)

# %%
import torch.optim as optim

#optimizer = optim.Adam(netG.parameters(), lr=0.001, weight_decay=1e-4)
optimizerG = optim.Adam(netG.parameters())
optimizerD = optim.Adam(netD.parameters())

# %%
print(f'MAX_EPOCH: {MAX_EPOCH}\nBATCH_SIZE: {BATCH_SIZE}\nUPSCALE_FACTOR: {UPSCALE_FACTOR}')
# Out:
# MAX_EPOCH: 100
# BATCH_SIZE: 64
# UPSCALE_FACTOR: 2

# %%
from torch.autograd import Variable
import gc

results = {'d_loss': [], 'g_loss': [], 'd_score': [], 'g_score': [], 'psnr': [], 'ssim': []}

SAVE_MODEL_INTERVAL = 10

for epoch in range(1, MAX_EPOCH + 1):
        train_bar = tqdm(train_loader)
        running_results = {'batch_sizes': 0, 'd_loss': 0, 'g_loss': 0, 'd_score': 0, 'g_score': 0}
    
        netG.train()
        netD.train()
        for data, target in train_bar:
            g_update_first = True
            batch_size = data.size(0)
            running_results['batch_sizes'] += batch_size
    
            ############################
            # (1) Update D network: maximize D(x)-1-D(G(z))
            ###########################
            real_img = Variable(target).to(device)
            z = Variable(data).to(device)
            fake_img = netG(z)
    
            netD.zero_grad()
            real_out = netD(real_img).mean()
            fake_out = netD(fake_img).mean()
            d_loss = 1 - real_out + fake_out
            d_loss.backward(retain_graph=True)
            optimizerD.step()
    
            ############################
            # (2) Update G network: minimize 1-D(G(z)) + Perception Loss + Image Loss + TV Loss
            ###########################
            netG.zero_grad()

            # add these two line to avoid runtime error
            fake_img = netG(z)
            fake_out = netD(fake_img).mean()

            g_loss = generator_criterion(fake_out, fake_img, real_img)        
            g_loss.backward()
            
            #fake_img = netG(z)
            #fake_out = netD(fake_img).mean()
            
            optimizerG.step()

            # loss for current batch before optimization 
            running_results['g_loss'] += g_loss.item() * batch_size
            running_results['d_loss'] += d_loss.item() * batch_size
            running_results['d_score'] += real_out.item() * batch_size
            running_results['g_score'] += fake_out.item() * batch_size
    
            train_bar.set_description(desc='[%d/%d] Loss_D: %.4f Loss_G: %.4f D(x): %.4f D(G(z)): %.4f' % (
                epoch, MAX_EPOCH, running_results['d_loss'] / running_results['batch_sizes'],
                running_results['g_loss'] / running_results['batch_sizes'],
                running_results['d_score'] / running_results['batch_sizes'],
                running_results['g_score'] / running_results['batch_sizes']))
    
        netG.eval()
        out_path = f'{SAVED_RESULTS_DIR}/training_results/SRF_' + str(UPSCALE_FACTOR) + '/'
        if not os.path.exists(out_path):
            os.makedirs(out_path)

        gc.collect()
        
        with torch.no_grad():
            val_bar = tqdm(val_loader)
            valing_results = {'mse': 0, 'ssims': 0, 'psnr': 0, 'ssim': 0, 'batch_sizes': 0}
            val_images = []
            for val_lr, val_hr_restore, val_hr in val_bar:
                batch_size = val_lr.size(0)
                valing_results['batch_sizes'] += batch_size
                lr = val_lr.to(device)
                hr = val_hr.to(device)

                sr = netG(lr)
        
                batch_mse = ((sr - hr) ** 2).data.mean()
                valing_results['mse'] += batch_mse * batch_size
                batch_ssim = pytorch_ssim.ssim(sr, hr).item()
                valing_results['ssims'] += batch_ssim * batch_size
                valing_results['psnr'] = 10 * log10((hr.max()**2) / (valing_results['mse'] / valing_results['batch_sizes']))
                valing_results['ssim'] = valing_results['ssims'] / valing_results['batch_sizes']
                val_bar.set_description(
                    desc='[converting LR images to SR images] PSNR: %.4f dB SSIM: %.4f' % (valing_results['psnr'], valing_results['ssim']))

                # only store few results
                if(len(val_images) < 30):
                  val_images.extend(
                      [display_transform()(val_hr_restore.squeeze(0)), display_transform()(hr.data.cpu().squeeze(0)),
                      display_transform()(sr.data.cpu().squeeze(0))])
                  
            val_images = torch.stack(val_images)
            val_images = torch.chunk(val_images, val_images.size(0) // 15)
            val_save_bar = tqdm(val_images, desc='[saving training results]')
            index = 1
            for image in val_save_bar:
                image = utils.make_grid(image, nrow=3, padding=5)
                utils.save_image(image, out_path + 'epoch_%d_index_%d.png' % (epoch, index), padding=5)
                index += 1
    
        gc.collect()

        # save model parameters
        if epoch % SAVE_MODEL_INTERVAL == 0:
          torch.save(netG, f'{SAVED_MODELS_DIR}/netG_epoch{epoch}_{UPSCALE_FACTOR}_cuda.pt')
          #torch.save(netD, f'{SAVED_MODELS_DIR}/netD_epoch{epoch}_{UPSCALE_FACTOR}_cuda.pt')

        # save loss\scores\psnr\ssim
        results['d_loss'].append(running_results['d_loss'] / running_results['batch_sizes'])
        results['g_loss'].append(running_results['g_loss'] / running_results['batch_sizes'])
        results['d_score'].append(running_results['d_score'] / running_results['batch_sizes'])
        results['g_score'].append(running_results['g_score'] / running_results['batch_sizes'])
        results['psnr'].append(valing_results['psnr'])
        results['ssim'].append(valing_results['ssim'])
    
        '''
        if epoch % 10 == 0 and epoch != 0:
            out_path = 'statistics/'
            data_frame = pd.DataFrame(
                data={'Loss_D': results['d_loss'], 'Loss_G': results['g_loss'], 'Score_D': results['d_score'],
                      'Score_G': results['g_score'], 'PSNR': results['psnr'], 'SSIM': results['ssim']},
                index=range(1, epoch + 1))
            data_frame.to_csv(out_path + 'srf_' + str(UPSCALE_FACTOR) + '_train_results.csv', index_label='Epoch')
        '''
# Out:
# [1/100] Loss_D: 0.9206 Loss_G: 0.0431 D(x): 0.3870 D(G(z)): 0.2532: 100%|██████████| 16/16 [00:19<00:00,  1.23s/it]
# [converting LR images to SR images] PSNR: 18.4173 dB SSIM: 0.5854: 100%|██████████| 30/30 [00:03<00:00,  9.49it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# [2/100] Loss_D: 0.8812 Loss_G: 0.0189 D(x): 0.4044 D(G(z)): 0.2626: 100%|██████████| 16/16 [00:17<00:00,  1.07s/it]
# [converting LR images to SR images] PSNR: 23.6851 dB SSIM: 0.7365: 100%|██████████| 30/30 [00:02<00:00, 11.58it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [3/100] Loss_D: 0.5904 Loss_G: 0.0162 D(x): 0.6068 D(G(z)): 0.1633: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 23.5246 dB SSIM: 0.8225: 100%|██████████| 30/30 [00:02<00:00, 11.63it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [4/100] Loss_D: 0.8465 Loss_G: 0.0137 D(x): 0.7607 D(G(z)): 0.5797: 100%|██████████| 16/16 [00:17<00:00,  1.09s/it]
# [converting LR images to SR images] PSNR: 23.4850 dB SSIM: 0.8237: 100%|██████████| 30/30 [00:02<00:00, 11.59it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# [5/100] Loss_D: 0.8538 Loss_G: 0.0121 D(x): 0.6269 D(G(z)): 0.4440: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 23.9907 dB SSIM: 0.8247: 100%|██████████| 30/30 [00:02<00:00, 11.19it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [6/100] Loss_D: 1.0143 Loss_G: 0.0111 D(x): 0.5564 D(G(z)): 0.5701: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 25.2245 dB SSIM: 0.8008: 100%|██████████| 30/30 [00:02<00:00, 11.44it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [7/100] Loss_D: 1.0046 Loss_G: 0.0100 D(x): 0.6027 D(G(z)): 0.6066: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 24.8160 dB SSIM: 0.8483: 100%|██████████| 30/30 [00:02<00:00, 11.41it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# [8/100] Loss_D: 1.0007 Loss_G: 0.0093 D(x): 0.6340 D(G(z)): 0.6363: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# [converting LR images to SR images] PSNR: 25.2062 dB SSIM: 0.8712: 100%|██████████| 30/30 [00:02<00:00, 11.39it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [9/100] Loss_D: 1.0037 Loss_G: 0.0086 D(x): 0.6394 D(G(z)): 0.6388: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 24.0224 dB SSIM: 0.8719: 100%|██████████| 30/30 [00:02<00:00, 11.54it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [10/100] Loss_D: 1.0000 Loss_G: 0.0087 D(x): 0.6414 D(G(z)): 0.6418: 100%|██████████| 16/16 [00:18<00:00,  1.15s/it]
# [converting LR images to SR images] PSNR: 23.3542 dB SSIM: 0.8556: 100%|██████████| 30/30 [00:02<00:00, 11.46it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [11/100] Loss_D: 1.0003 Loss_G: 0.0077 D(x): 0.6593 D(G(z)): 0.6523: 100%|██████████| 16/16 [00:17<00:00,  1.07s/it]
# [converting LR images to SR images] PSNR: 27.3755 dB SSIM: 0.9006: 100%|██████████| 30/30 [00:02<00:00, 11.48it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [12/100] Loss_D: 0.9962 Loss_G: 0.0075 D(x): 0.6423 D(G(z)): 0.6367: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 22.2067 dB SSIM: 0.8829: 100%|██████████| 30/30 [00:02<00:00, 11.35it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [13/100] Loss_D: 0.9891 Loss_G: 0.0076 D(x): 0.7059 D(G(z)): 0.6931: 100%|██████████| 16/16 [00:18<00:00,  1.15s/it]
# [converting LR images to SR images] PSNR: 27.7268 dB SSIM: 0.8763: 100%|██████████| 30/30 [00:02<00:00, 11.47it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [14/100] Loss_D: 0.9945 Loss_G: 0.0072 D(x): 0.7186 D(G(z)): 0.7094: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# [converting LR images to SR images] PSNR: 26.5167 dB SSIM: 0.8495: 100%|██████████| 30/30 [00:02<00:00, 11.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [15/100] Loss_D: 0.9990 Loss_G: 0.0067 D(x): 0.6385 D(G(z)): 0.6347: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 28.6774 dB SSIM: 0.8926: 100%|██████████| 30/30 [00:02<00:00, 11.19it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [16/100] Loss_D: 0.9949 Loss_G: 0.0061 D(x): 0.6845 D(G(z)): 0.6743: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# [converting LR images to SR images] PSNR: 27.4145 dB SSIM: 0.8718: 100%|██████████| 30/30 [00:02<00:00, 11.25it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [17/100] Loss_D: 1.0106 Loss_G: 0.0061 D(x): 0.6704 D(G(z)): 0.6812: 100%|██████████| 16/16 [00:17<00:00,  1.09s/it]
# [converting LR images to SR images] PSNR: 28.6641 dB SSIM: 0.9045: 100%|██████████| 30/30 [00:02<00:00, 11.41it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [18/100] Loss_D: 1.0010 Loss_G: 0.0059 D(x): 0.6951 D(G(z)): 0.6952: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 27.1018 dB SSIM: 0.9141: 100%|██████████| 30/30 [00:02<00:00, 11.36it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [19/100] Loss_D: 1.0002 Loss_G: 0.0067 D(x): 0.7383 D(G(z)): 0.7408: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 23.9111 dB SSIM: 0.8930: 100%|██████████| 30/30 [00:02<00:00, 11.28it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [20/100] Loss_D: 1.0001 Loss_G: 0.0056 D(x): 0.7784 D(G(z)): 0.7775: 100%|██████████| 16/16 [00:17<00:00,  1.08s/it]
# [converting LR images to SR images] PSNR: 28.0929 dB SSIM: 0.8976: 100%|██████████| 30/30 [00:02<00:00, 11.54it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [21/100] Loss_D: 1.0006 Loss_G: 0.0055 D(x): 0.7374 D(G(z)): 0.7369: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 27.0862 dB SSIM: 0.9084: 100%|██████████| 30/30 [00:02<00:00, 11.42it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [22/100] Loss_D: 1.0013 Loss_G: 0.0053 D(x): 0.7231 D(G(z)): 0.7218: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 28.1311 dB SSIM: 0.9109: 100%|██████████| 30/30 [00:02<00:00, 11.48it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [23/100] Loss_D: 0.9981 Loss_G: 0.0053 D(x): 0.6706 D(G(z)): 0.6624: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 25.1716 dB SSIM: 0.9190: 100%|██████████| 30/30 [00:02<00:00, 11.42it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [24/100] Loss_D: 0.9973 Loss_G: 0.0054 D(x): 0.6531 D(G(z)): 0.6506: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 27.9458 dB SSIM: 0.9262: 100%|██████████| 30/30 [00:02<00:00, 11.45it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# [25/100] Loss_D: 1.0032 Loss_G: 0.0050 D(x): 0.6247 D(G(z)): 0.6197: 100%|██████████| 16/16 [00:18<00:00,  1.18s/it]
# [converting LR images to SR images] PSNR: 26.5016 dB SSIM: 0.9154: 100%|██████████| 30/30 [00:02<00:00, 11.47it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [26/100] Loss_D: 1.0026 Loss_G: 0.0048 D(x): 0.5545 D(G(z)): 0.5567: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 27.2936 dB SSIM: 0.9312: 100%|██████████| 30/30 [00:02<00:00, 11.50it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# [27/100] Loss_D: 1.0056 Loss_G: 0.0051 D(x): 0.4647 D(G(z)): 0.4520: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# [converting LR images to SR images] PSNR: 27.2686 dB SSIM: 0.9180: 100%|██████████| 30/30 [00:02<00:00, 11.46it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [28/100] Loss_D: 1.0044 Loss_G: 0.0051 D(x): 0.3690 D(G(z)): 0.3751: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 26.0773 dB SSIM: 0.9218: 100%|██████████| 30/30 [00:02<00:00, 11.49it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [29/100] Loss_D: 1.0145 Loss_G: 0.0058 D(x): 0.3529 D(G(z)): 0.3632: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 25.4914 dB SSIM: 0.9217: 100%|██████████| 30/30 [00:02<00:00, 11.41it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# [30/100] Loss_D: 1.0091 Loss_G: 0.0052 D(x): 0.3673 D(G(z)): 0.3656: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 26.0435 dB SSIM: 0.9291: 100%|██████████| 30/30 [00:02<00:00, 11.53it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# [31/100] Loss_D: 1.0074 Loss_G: 0.0051 D(x): 0.3353 D(G(z)): 0.3417: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 29.4158 dB SSIM: 0.9193: 100%|██████████| 30/30 [00:02<00:00, 11.36it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [32/100] Loss_D: 1.0057 Loss_G: 0.0051 D(x): 0.3630 D(G(z)): 0.3699: 100%|██████████| 16/16 [00:17<00:00,  1.09s/it]
# [converting LR images to SR images] PSNR: 29.1683 dB SSIM: 0.9217: 100%|██████████| 30/30 [00:02<00:00, 11.35it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [33/100] Loss_D: 1.0109 Loss_G: 0.0052 D(x): 0.3941 D(G(z)): 0.4045: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 30.4061 dB SSIM: 0.9222: 100%|██████████| 30/30 [00:02<00:00, 11.26it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [34/100] Loss_D: 1.0071 Loss_G: 0.0049 D(x): 0.4176 D(G(z)): 0.4243: 100%|██████████| 16/16 [00:17<00:00,  1.09s/it]
# [converting LR images to SR images] PSNR: 27.3276 dB SSIM: 0.9103: 100%|██████████| 30/30 [00:02<00:00, 11.47it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [35/100] Loss_D: 0.9975 Loss_G: 0.0054 D(x): 0.4467 D(G(z)): 0.4446: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# [converting LR images to SR images] PSNR: 25.6121 dB SSIM: 0.9286: 100%|██████████| 30/30 [00:02<00:00, 11.38it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# [36/100] Loss_D: 1.0050 Loss_G: 0.0058 D(x): 0.4458 D(G(z)): 0.4452: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# [converting LR images to SR images] PSNR: 25.2833 dB SSIM: 0.9247: 100%|██████████| 30/30 [00:02<00:00, 11.20it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [37/100] Loss_D: 1.0059 Loss_G: 0.0050 D(x): 0.4748 D(G(z)): 0.4849: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 23.8469 dB SSIM: 0.9246: 100%|██████████| 30/30 [00:02<00:00, 11.27it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [38/100] Loss_D: 1.0052 Loss_G: 0.0046 D(x): 0.5528 D(G(z)): 0.5630: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 27.9537 dB SSIM: 0.9260: 100%|██████████| 30/30 [00:02<00:00, 11.21it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [39/100] Loss_D: 1.0014 Loss_G: 0.0046 D(x): 0.5501 D(G(z)): 0.5484: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 26.6662 dB SSIM: 0.9215: 100%|██████████| 30/30 [00:02<00:00, 11.20it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [40/100] Loss_D: 1.0064 Loss_G: 0.0051 D(x): 0.5422 D(G(z)): 0.5526: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 22.8808 dB SSIM: 0.9240: 100%|██████████| 30/30 [00:02<00:00, 11.20it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [41/100] Loss_D: 1.0037 Loss_G: 0.0048 D(x): 0.5797 D(G(z)): 0.5828: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 28.0838 dB SSIM: 0.9213: 100%|██████████| 30/30 [00:02<00:00, 11.22it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [42/100] Loss_D: 1.0025 Loss_G: 0.0045 D(x): 0.5516 D(G(z)): 0.5511: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 25.1501 dB SSIM: 0.9370: 100%|██████████| 30/30 [00:02<00:00, 11.49it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [43/100] Loss_D: 1.0116 Loss_G: 0.0045 D(x): 0.5318 D(G(z)): 0.5284: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 23.5144 dB SSIM: 0.9168: 100%|██████████| 30/30 [00:02<00:00, 11.12it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [44/100] Loss_D: 1.0064 Loss_G: 0.0048 D(x): 0.4674 D(G(z)): 0.4706: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 29.5066 dB SSIM: 0.9327: 100%|██████████| 30/30 [00:02<00:00, 11.11it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [45/100] Loss_D: 1.0050 Loss_G: 0.0043 D(x): 0.4411 D(G(z)): 0.4411: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 27.4701 dB SSIM: 0.9403: 100%|██████████| 30/30 [00:02<00:00, 11.07it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# [46/100] Loss_D: 1.0049 Loss_G: 0.0041 D(x): 0.4369 D(G(z)): 0.4412: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 30.4634 dB SSIM: 0.9431: 100%|██████████| 30/30 [00:02<00:00, 10.96it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [47/100] Loss_D: 1.0038 Loss_G: 0.0042 D(x): 0.4307 D(G(z)): 0.4299: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 28.0832 dB SSIM: 0.9360: 100%|██████████| 30/30 [00:02<00:00, 11.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [48/100] Loss_D: 1.0046 Loss_G: 0.0045 D(x): 0.3957 D(G(z)): 0.4016: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 28.5002 dB SSIM: 0.9334: 100%|██████████| 30/30 [00:02<00:00, 11.15it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [49/100] Loss_D: 1.0071 Loss_G: 0.0044 D(x): 0.3875 D(G(z)): 0.3920: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 29.0549 dB SSIM: 0.9456: 100%|██████████| 30/30 [00:02<00:00, 11.20it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [50/100] Loss_D: 1.0034 Loss_G: 0.0044 D(x): 0.4211 D(G(z)): 0.4286: 100%|██████████| 16/16 [00:18<00:00,  1.15s/it]
# [converting LR images to SR images] PSNR: 29.2315 dB SSIM: 0.9460: 100%|██████████| 30/30 [00:02<00:00, 11.07it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [51/100] Loss_D: 1.0014 Loss_G: 0.0040 D(x): 0.4528 D(G(z)): 0.4500: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 29.8697 dB SSIM: 0.9370: 100%|██████████| 30/30 [00:02<00:00, 11.23it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [52/100] Loss_D: 1.0082 Loss_G: 0.0043 D(x): 0.3819 D(G(z)): 0.3821: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 26.0246 dB SSIM: 0.9423: 100%|██████████| 30/30 [00:02<00:00, 11.22it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# [53/100] Loss_D: 1.0103 Loss_G: 0.0041 D(x): 0.3417 D(G(z)): 0.3491: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 30.3226 dB SSIM: 0.9424: 100%|██████████| 30/30 [00:02<00:00, 11.18it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [54/100] Loss_D: 1.0062 Loss_G: 0.0041 D(x): 0.3069 D(G(z)): 0.3120: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 29.1335 dB SSIM: 0.9470: 100%|██████████| 30/30 [00:02<00:00, 11.21it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [55/100] Loss_D: 1.0005 Loss_G: 0.0039 D(x): 0.3166 D(G(z)): 0.3150: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 28.4342 dB SSIM: 0.9476: 100%|██████████| 30/30 [00:02<00:00, 11.35it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [56/100] Loss_D: 1.0005 Loss_G: 0.0041 D(x): 0.2975 D(G(z)): 0.2978: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 29.2827 dB SSIM: 0.9380: 100%|██████████| 30/30 [00:02<00:00, 11.35it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [57/100] Loss_D: 1.0044 Loss_G: 0.0038 D(x): 0.3091 D(G(z)): 0.3143: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 31.0006 dB SSIM: 0.9393: 100%|██████████| 30/30 [00:02<00:00, 11.23it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [58/100] Loss_D: 1.0039 Loss_G: 0.0038 D(x): 0.3318 D(G(z)): 0.3352: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 31.9214 dB SSIM: 0.9492: 100%|██████████| 30/30 [00:02<00:00, 11.29it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [59/100] Loss_D: 1.0055 Loss_G: 0.0038 D(x): 0.3728 D(G(z)): 0.3838: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 28.7899 dB SSIM: 0.9431: 100%|██████████| 30/30 [00:02<00:00, 11.12it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# [60/100] Loss_D: 1.0005 Loss_G: 0.0038 D(x): 0.3750 D(G(z)): 0.3728: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 31.0234 dB SSIM: 0.9458: 100%|██████████| 30/30 [00:02<00:00, 11.44it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [61/100] Loss_D: 0.9971 Loss_G: 0.0036 D(x): 0.3121 D(G(z)): 0.3067: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 30.8386 dB SSIM: 0.9490: 100%|██████████| 30/30 [00:02<00:00, 11.23it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [62/100] Loss_D: 1.0050 Loss_G: 0.0039 D(x): 0.3009 D(G(z)): 0.3043: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 26.3317 dB SSIM: 0.9427: 100%|██████████| 30/30 [00:02<00:00, 11.10it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [63/100] Loss_D: 1.0005 Loss_G: 0.0043 D(x): 0.2904 D(G(z)): 0.2895: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 31.0966 dB SSIM: 0.9501: 100%|██████████| 30/30 [00:02<00:00, 11.02it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [64/100] Loss_D: 1.0014 Loss_G: 0.0038 D(x): 0.2794 D(G(z)): 0.2778: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 28.5808 dB SSIM: 0.9512: 100%|██████████| 30/30 [00:02<00:00, 11.08it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [65/100] Loss_D: 1.0025 Loss_G: 0.0042 D(x): 0.2717 D(G(z)): 0.2724: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 23.9690 dB SSIM: 0.9336: 100%|██████████| 30/30 [00:02<00:00, 10.89it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [66/100] Loss_D: 1.0054 Loss_G: 0.0041 D(x): 0.2751 D(G(z)): 0.2818: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 28.5732 dB SSIM: 0.9443: 100%|██████████| 30/30 [00:02<00:00, 11.22it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [67/100] Loss_D: 1.0091 Loss_G: 0.0040 D(x): 0.2999 D(G(z)): 0.3107: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 29.3388 dB SSIM: 0.9436: 100%|██████████| 30/30 [00:02<00:00, 11.25it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [68/100] Loss_D: 1.0068 Loss_G: 0.0039 D(x): 0.3114 D(G(z)): 0.3159: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# [converting LR images to SR images] PSNR: 30.9056 dB SSIM: 0.9517: 100%|██████████| 30/30 [00:02<00:00, 11.18it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [69/100] Loss_D: 1.0030 Loss_G: 0.0038 D(x): 0.2823 D(G(z)): 0.2799: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 29.1889 dB SSIM: 0.9426: 100%|██████████| 30/30 [00:02<00:00, 11.39it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [70/100] Loss_D: 1.0055 Loss_G: 0.0039 D(x): 0.2292 D(G(z)): 0.2311: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 31.7911 dB SSIM: 0.9497: 100%|██████████| 30/30 [00:02<00:00, 11.13it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [71/100] Loss_D: 1.0062 Loss_G: 0.0037 D(x): 0.2136 D(G(z)): 0.2156: 100%|██████████| 16/16 [00:18<00:00,  1.15s/it]
# [converting LR images to SR images] PSNR: 29.1768 dB SSIM: 0.9538: 100%|██████████| 30/30 [00:02<00:00, 11.12it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# [72/100] Loss_D: 0.9994 Loss_G: 0.0038 D(x): 0.2030 D(G(z)): 0.2031: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# [converting LR images to SR images] PSNR: 30.1580 dB SSIM: 0.9510: 100%|██████████| 30/30 [00:02<00:00, 11.08it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# [73/100] Loss_D: 0.9977 Loss_G: 0.0038 D(x): 0.2150 D(G(z)): 0.2113: 100%|██████████| 16/16 [00:18<00:00,  1.16s/it]
# [converting LR images to SR images] PSNR: 30.1869 dB SSIM: 0.9511: 100%|██████████| 30/30 [00:02<00:00, 11.23it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [74/100] Loss_D: 1.0004 Loss_G: 0.0037 D(x): 0.2158 D(G(z)): 0.2182: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 31.3779 dB SSIM: 0.9527: 100%|██████████| 30/30 [00:02<00:00, 11.11it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [75/100] Loss_D: 1.0012 Loss_G: 0.0036 D(x): 0.2543 D(G(z)): 0.2563: 100%|██████████| 16/16 [00:17<00:00,  1.09s/it]
# [converting LR images to SR images] PSNR: 31.2083 dB SSIM: 0.9540: 100%|██████████| 30/30 [00:02<00:00, 10.98it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [76/100] Loss_D: 1.0029 Loss_G: 0.0036 D(x): 0.2504 D(G(z)): 0.2492: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 27.3358 dB SSIM: 0.9495: 100%|██████████| 30/30 [00:02<00:00, 11.14it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [77/100] Loss_D: 0.9993 Loss_G: 0.0038 D(x): 0.2262 D(G(z)): 0.2246: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 29.0238 dB SSIM: 0.9515: 100%|██████████| 30/30 [00:02<00:00, 11.05it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [78/100] Loss_D: 1.0008 Loss_G: 0.0037 D(x): 0.2500 D(G(z)): 0.2530: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 31.8593 dB SSIM: 0.9552: 100%|██████████| 30/30 [00:02<00:00, 11.46it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# [79/100] Loss_D: 1.0013 Loss_G: 0.0035 D(x): 0.3271 D(G(z)): 0.3349: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 29.7557 dB SSIM: 0.9515: 100%|██████████| 30/30 [00:02<00:00, 11.20it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [80/100] Loss_D: 1.0040 Loss_G: 0.0036 D(x): 0.3039 D(G(z)): 0.3063: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 30.0382 dB SSIM: 0.9540: 100%|██████████| 30/30 [00:02<00:00, 11.06it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# [81/100] Loss_D: 0.9953 Loss_G: 0.0036 D(x): 0.3080 D(G(z)): 0.3033: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 26.5128 dB SSIM: 0.9473: 100%|██████████| 30/30 [00:02<00:00, 11.07it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# [82/100] Loss_D: 1.0051 Loss_G: 0.0035 D(x): 0.3043 D(G(z)): 0.3055: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# [converting LR images to SR images] PSNR: 30.6406 dB SSIM: 0.9558: 100%|██████████| 30/30 [00:02<00:00, 11.33it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [83/100] Loss_D: 1.0052 Loss_G: 0.0039 D(x): 0.2573 D(G(z)): 0.2585: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# [converting LR images to SR images] PSNR: 27.7022 dB SSIM: 0.9464: 100%|██████████| 30/30 [00:02<00:00, 11.36it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [84/100] Loss_D: 1.0043 Loss_G: 0.0035 D(x): 0.2516 D(G(z)): 0.2559: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 28.9079 dB SSIM: 0.9523: 100%|██████████| 30/30 [00:02<00:00, 11.18it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [85/100] Loss_D: 1.0017 Loss_G: 0.0034 D(x): 0.2491 D(G(z)): 0.2503: 100%|██████████| 16/16 [00:18<00:00,  1.15s/it]
# [converting LR images to SR images] PSNR: 28.1562 dB SSIM: 0.9535: 100%|██████████| 30/30 [00:02<00:00, 11.06it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# [86/100] Loss_D: 1.0024 Loss_G: 0.0034 D(x): 0.2823 D(G(z)): 0.2857: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 31.1378 dB SSIM: 0.9548: 100%|██████████| 30/30 [00:02<00:00, 11.28it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# [87/100] Loss_D: 1.0060 Loss_G: 0.0032 D(x): 0.2853 D(G(z)): 0.2895: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 31.0955 dB SSIM: 0.9559: 100%|██████████| 30/30 [00:02<00:00, 11.26it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# [88/100] Loss_D: 1.0021 Loss_G: 0.0034 D(x): 0.2763 D(G(z)): 0.2769: 100%|██████████| 16/16 [00:18<00:00,  1.15s/it]
# [converting LR images to SR images] PSNR: 31.5278 dB SSIM: 0.9532: 100%|██████████| 30/30 [00:02<00:00, 11.36it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [89/100] Loss_D: 0.9986 Loss_G: 0.0033 D(x): 0.2671 D(G(z)): 0.2644: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 31.1558 dB SSIM: 0.9539: 100%|██████████| 30/30 [00:02<00:00, 11.08it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# [90/100] Loss_D: 1.0042 Loss_G: 0.0031 D(x): 0.2683 D(G(z)): 0.2751: 100%|██████████| 16/16 [00:18<00:00,  1.15s/it]
# [converting LR images to SR images] PSNR: 32.0854 dB SSIM: 0.9577: 100%|██████████| 30/30 [00:02<00:00, 11.34it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [91/100] Loss_D: 1.0098 Loss_G: 0.0030 D(x): 0.2776 D(G(z)): 0.2862: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 30.1505 dB SSIM: 0.9559: 100%|██████████| 30/30 [00:02<00:00, 11.15it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [92/100] Loss_D: 1.0085 Loss_G: 0.0039 D(x): 0.2701 D(G(z)): 0.2747: 100%|██████████| 16/16 [00:18<00:00,  1.16s/it]
# [converting LR images to SR images] PSNR: 25.8496 dB SSIM: 0.9448: 100%|██████████| 30/30 [00:02<00:00, 11.27it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [93/100] Loss_D: 1.0050 Loss_G: 0.0034 D(x): 0.2661 D(G(z)): 0.2711: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 30.3687 dB SSIM: 0.9529: 100%|██████████| 30/30 [00:02<00:00, 11.05it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [94/100] Loss_D: 1.0048 Loss_G: 0.0035 D(x): 0.2639 D(G(z)): 0.2685: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# [converting LR images to SR images] PSNR: 31.2028 dB SSIM: 0.9546: 100%|██████████| 30/30 [00:02<00:00, 11.21it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [95/100] Loss_D: 1.0019 Loss_G: 0.0033 D(x): 0.2654 D(G(z)): 0.2675: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 27.8625 dB SSIM: 0.9554: 100%|██████████| 30/30 [00:02<00:00, 11.12it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# [96/100] Loss_D: 1.0014 Loss_G: 0.0035 D(x): 0.2540 D(G(z)): 0.2516: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# [converting LR images to SR images] PSNR: 30.1610 dB SSIM: 0.9511: 100%|██████████| 30/30 [00:02<00:00, 11.21it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [97/100] Loss_D: 1.0027 Loss_G: 0.0033 D(x): 0.2334 D(G(z)): 0.2359: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# [converting LR images to SR images] PSNR: 30.5064 dB SSIM: 0.9568: 100%|██████████| 30/30 [00:02<00:00, 11.15it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [98/100] Loss_D: 1.0084 Loss_G: 0.0031 D(x): 0.2519 D(G(z)): 0.2617: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 31.0841 dB SSIM: 0.9589: 100%|██████████| 30/30 [00:02<00:00, 11.22it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# [99/100] Loss_D: 1.0066 Loss_G: 0.0032 D(x): 0.2622 D(G(z)): 0.2687: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# [converting LR images to SR images] PSNR: 32.0408 dB SSIM: 0.9593: 100%|██████████| 30/30 [00:02<00:00, 11.38it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# [100/100] Loss_D: 0.9981 Loss_G: 0.0030 D(x): 0.2779 D(G(z)): 0.2762: 100%|██████████| 16/16 [00:18<00:00,  1.17s/it]
# [converting LR images to SR images] PSNR: 31.9237 dB SSIM: 0.9539: 100%|██████████| 30/30 [00:02<00:00, 11.33it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]

# %%
torch.save(netG, f'{SAVED_MODELS_DIR}/srgan_netG_cuda.pt')
torch.save(netD, f'{SAVED_MODELS_DIR}/srgan_netD_cuda.pt')

# %%
def plot_losses(titlename, results, save_filename=None):
    start_idx = 0
    fig, axs = plt.subplots(figsize=(14,8))

    x_size = len(results['d_loss'])-start_idx

    legend_list = ['discriminitive_loss', 'generative_loss']

    # plot losses
    axs.plot(range(0,x_size), results['d_loss'][start_idx:])
    axs.plot(range(0,x_size), results['g_loss'][start_idx:])

    axs.set_title(titlename)
    axs.set_ylabel('Losses')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,x_size+1),x_size/10)
    axs.legend(legend_list, loc='best')
    plt.show()

    if(save_filename != None):
      fig.savefig(save_filename)

def plot_scores(titlename, results, save_filename=None):
    start_idx = 0
    fig, axs = plt.subplots(figsize=(14,8))

    x_size = len(results['d_score'])-start_idx

    legend_list = ['discriminitive_score', 'generative_score']

    # plot losses
    axs.plot(range(0,x_size), results['d_score'][start_idx:])
    axs.plot(range(0,x_size), results['g_score'][start_idx:])

    axs.set_title(titlename)
    axs.set_ylabel('Scores')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,x_size+1),x_size/10)
    axs.legend(legend_list, loc='best')
    plt.show()

    if(save_filename != None):
      fig.savefig(save_filename)

def plot_psnr_ssim(titlename, results, save_filename=None):
    start_idx = 0
    fig, axs = plt.subplots(figsize=(14,8))

    x_size = len(results['psnr'])-start_idx

    legend_list = ['psnr', 'ssim']

    # plot losses
    axs.plot(range(0,x_size), results['psnr'][start_idx:])
    axs.plot(range(0,x_size), results['ssim'][start_idx:])

    axs.set_title(titlename)
    axs.set_ylabel('Values')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,x_size+1),x_size/10)
    axs.legend(legend_list, loc='best')
    plt.show()

    if(save_filename != None):
      fig.savefig(save_filename)

# %%
plot_losses(MODEL_NAME, results, f'{PLOT_DIR}/losses_plot.jpg' )

# %%
plot_scores(MODEL_NAME, results, f'{PLOT_DIR}/scores_plot.jpg' )

# %%
plot_psnr_ssim(MODEL_NAME, results, f'{PLOT_DIR}/psnr_ssim_plot.jpg' )

# %%
g_model = torch.load(f'{SAVED_MODELS_DIR}/srgan_netG_cuda.pt')

# %%
g_model = g_model.to(device)
g_model.eval()
# Out:
# Generator(
#   (block1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#     (1): PReLU(num_parameters=1)
#   )
#   (block2): ResidualBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block3): ResidualBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block4): ResidualBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block5): ResidualBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block6): ResidualBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block7): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block8): Sequential(
#     (0): UpsampleBLock(
#       (conv): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (pixel_shuffle): PixelShuffle(upscale_factor=2)
#       (prelu): PReLU(num_parameters=1)
#     )
#     (1): Conv2d(64, 3, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#   )
# )

# %%
# !ls '/content/gdrive/My Drive/EVA4Phase2/test/Lq'
# Out:
#  drone-3620334__340.jpg
#  drone-3698585_640.jpg
#  drone-3723148__340.jpg
#  drone-3845299__340.jpg
#  drone-3926137__340.jpg
#  drone-4002251__340.jpg
#  drone-4179093__340.jpg
#  drone-4206870__340.jpg
#  drone-4233859__340.jpg
#  drone-4280956__340.jpg
#  drone-4302861__340.jpg
#  drone-4308659__340.jpg
#  drone-4488206__340.jpg
#  drone-4634946__340.jpg
#  drone-4638280__340.jpg
#  drone-4937709__340.jpg
#  drone-5099737__340.jpg
#  drone-5118888__340.jpg
#  drone-5231539__340.jpg
#  drone-5282561__340.jpg
#  drone-5401406__340.jpg
#  drone-aed_wide-f963e6c8a0dc553c7659d3847fd1c2c0ce5a087d.jpg
#  drone-aerial-graphy-camera-helicopter-unmanned-landscape-digital-quadcopter-technology.jpg
#  drone-afp.jpg
# 'drone-assassination (1).jpg'
#  drone-assassination.jpg
#  drone-at-airport.jpg
#  drone-at-night-580x387.jpg
#  drone-attack-controled-terrorist-attacking-to-nuclear-power-plant-digital-artwork-fictional-vehicles-uav-theme-60858609.jpg
#  drone-delivery-a-look-at-the-current-regulations-across-globe.jpg

# %%
from torchvision.transforms import CenterCrop, ToTensor, Resize

def calculate_valid_crop_size(crop_size, upscale_factor):
    return crop_size - (crop_size % upscale_factor)

def get_sample_images(real_image, upscale_factor):
    w, h = real_image.size
    crop_size = calculate_valid_crop_size(min(w, h), upscale_factor)
    lr_scale = Resize(crop_size // upscale_factor, interpolation=Image.BICUBIC)
    hr_scale = Resize(crop_size, interpolation=Image.BICUBIC)
    hr_image = CenterCrop(crop_size)(real_image)
    lr_image = lr_scale(hr_image)
    hr_restore_img = hr_scale(lr_image)
    return ToTensor()(lr_image), ToTensor()(hr_restore_img), ToTensor()(hr_image)

# %%
test_img_path = '/content/gdrive/My Drive/EVA4Phase2/test/Lq'
test_img = f'{test_img_path}/drone-aed_wide-f963e6c8a0dc553c7659d3847fd1c2c0ce5a087d.jpg'
real_image = Image.open(test_img).convert('RGB')
lr, hr_restore, hr = get_sample_images(real_image, UPSCALE_FACTOR)

# %%
lr = lr.unsqueeze(0).to(device)
sr = g_model(lr)
sr, lr = sr.squeeze(0), lr.squeeze(0)

# %%
def show_result_ext(hr, hr_restore, sr):
    imgs = torch.cat([hr_restore.cpu(), hr.cpu(), sr.cpu()], dim=2)
    imgs = np.transpose(imgs.cpu().detach().numpy(),[1,2,0])
    fig = plt.figure(figsize=(10, 3))
    plt.imshow(imgs)

def show_result(hr, hr_restore, sr, save_filename=None):
    fig = plt.figure(figsize=(10,3))

    cnt=1
    ax = fig.add_subplot(1,3, cnt, xticks=[], yticks=[])
    ax.axis('off')
    ax.set_title("HR Restored")
    plt.imshow(np.transpose(hr_restore.cpu().detach().numpy(),[1,2,0]))
    
    cnt += 1
    ax = fig.add_subplot(1,3, cnt, xticks=[], yticks=[])
    ax.axis('off')
    ax.set_title('HR')
    plt.imshow(np.transpose(hr.cpu().detach().numpy(),[1,2,0]))

    cnt += 1
    ax = fig.add_subplot(1,3, cnt, xticks=[], yticks=[])
    ax.axis('off')
    ax.set_title('Super Resolution')
    plt.imshow(np.transpose(sr.cpu().detach().numpy(),[1,2,0]))

    if save_filename:
      fig.savefig(save_filename)

# %%
show_result(hr, hr_restore, sr, f'{PLOT_DIR}/result.jpg')
